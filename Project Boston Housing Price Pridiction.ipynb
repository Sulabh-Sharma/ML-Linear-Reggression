# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('housing.data',header = None,delim_whitespace = True)

# %%
col = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df.columns = col

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
sns.boxplot(x='CRIM', y ='MEDV', data=df)

# %%
sns.jointplot(x=df['CRIM'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['ZN'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['INDUS'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['CHAS'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['NOX'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['RM'],y=df['MEDV'],kind = 'reg')
sns.jointplot(x=df['AGE'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['DIS'],y=df['MEDV'],kind = 'reg')
sns.jointplot(x=df['DIS'],y=df['MEDV'],kind = 'hex')

# %%
sns.jointplot(x=df['RAD'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['TAX'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['PTRATIO'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['B'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['LSTAT'],y=df['MEDV'],kind = 'reg')

# %%
sns.jointplot(x=df['MEDV'],y=df['MEDV'],kind = 'reg')

# %%
x= df.iloc[:,:13]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y=df.iloc[:,13:]

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# 5    28.7
# 6    22.9
# 7    27.1
# 8    16.5
# 9    18.9
# 10   15.0
# 11   18.9
# 12   21.7
# 13   20.4
# 14   18.2
# 15   19.9
# 16   23.1
# 17   17.5
# 18   20.2
# 19   18.2
# 20   13.6
# 21   19.6
# 22   15.2
# 23   14.5
# 24   15.6
# 25   13.9
# 26   16.6
# 27   14.8
# 28   18.4
# 29   21.0
# ..    ...
# 476  16.7
# 477  12.0
# 478  14.6
# 479  21.4
# 480  23.0
# 481  23.7
# 482  25.0
# 483  21.8
# 484  20.6
# 485  21.2
# 486  19.1
# 487  20.6
# 488  15.2
# 489   7.0
# 490   8.1
# 491  13.6
# 492  20.1
# 493  21.8
# 494  24.5
# 495  23.1
# 496  19.7
# 497  18.3
# 498  21.2
# 499  17.5
# 500  16.8
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.4,random_state=3)

# %%
x_train.head()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 75   0.09512  0.0  12.83     0  0.437  6.286   45.0  4.5026    5  398.0
# 142  3.32105  0.0  19.58     1  0.871  5.403  100.0  1.3216    5  403.0
# 47   0.22927  0.0   6.91     0  0.448  6.030   85.5  5.6894    3  233.0
# 46   0.18836  0.0   6.91     0  0.448  5.786   33.3  5.1004    3  233.0
# 70   0.08826  0.0  10.81     0  0.413  6.417    6.6  5.2873    4  305.0
#
#      PTRATIO       B  LSTAT
# 75      18.7  383.23   8.94
# 142     14.7  396.90  26.82
# 47      17.9  392.74  18.80
# 46      17.9  396.90  14.15
# 70      19.2  383.73   6.72

# %%
y_train.head()
# Out:
#      MEDV
# 75   21.4
# 142  13.4
# 47   16.6
# 46   20.0
# 70   24.2

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
make = model.predict(x_test)

# %%
x_test.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 224  0.31533   0.0   6.20     0  0.504  8.266  78.3  2.8944    8  307.0
# 137  0.35233   0.0  21.89     0  0.624  6.454  98.4  1.8498    4  437.0
# 453  8.24809   0.0  18.10     0  0.713  7.393  99.3  2.4527   24  666.0
# 303  0.10000  34.0   6.09     0  0.433  6.982  17.7  5.4917    7  329.0
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315.0
#
#      PTRATIO       B  LSTAT
# 224     17.4  385.05   4.14
# 137     21.2  394.08  14.59
# 453     20.2  375.87  16.74
# 303     16.1  390.43   4.86
# 254     16.4  392.89   6.57

# %%
y_test
# Out:
#      MEDV
# 224  44.8
# 137  17.1
# 453  17.8
# 303  33.1
# 254  21.9
# 37   21.0
# 442  18.4
# 417  10.4
# 16   23.1
# 209  20.0
# 126  15.7
# 157  41.3
# 196  33.3
# 266  30.7
# 404   8.5
# 399   6.3
# 116  21.2
# 127  16.2
# 134  15.6
# 201  24.1
# 503  23.9
# 161  50.0
# 287  23.2
# 73   23.4
# 439  12.8
# 325  24.6
# 112  18.8
# 310  16.1
# 14   18.2
# 230  24.3
# ..    ...
# 82   24.8
# 478  14.6
# 53   23.4
# 260  33.8
# 84   23.9
# 436   9.6
# 493  21.8
# 227  31.6
# 430  14.5
# 385   7.2
# 74   24.1
# 464  21.4
# 411  17.2
# 282  46.0
# 321  23.1
# 23   14.5
# 247  20.5
# 154  17.0
# 233  48.3
# 191  30.5
# 484  20.6
# 18   20.2
# 296  27.1
# 50   19.7
# 38   24.7
# 193  31.1
# 288  22.3
# 188  29.8
# 491  13.6
# 5    28.7
#
# [203 rows x 1 columns]

# %%
make
# Out:
# array([[37.28310775],
#        [19.37171451],
#        [23.06750533],
#        [32.24960658],
#        [25.54420754],
#        [22.7960988 ],
#        [19.90585171],
#        [ 6.22359646],
#        [20.85198078],
#        [17.60182577],
#        [12.03752876],
#        [32.99605364],
#        [36.53544505],
#        [30.21065858],
#        [ 6.47058938],
#        [10.30278772],
#        [23.42888714],
#        [15.27325219],
#        [13.38501292],
#        [29.85926629],
#        [27.39324638],
#        [36.44589485],
#        [27.36802638],
#        [23.21146916],
#        [13.79116955],
#        [24.62190652],
#        [20.74207347],
#        [17.79671339],
#        [19.9581423 ],
#        [24.02272919],
#        [14.84531883],
#        [33.69519775],
#        [22.11705112],
#        [19.44463412],
#        [18.70007563],
#        [17.19374234],
#        [22.19250331],
#        [32.43965554],
#        [16.98733259],
#        [22.07939549],
#        [18.08820159],
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.7369068178995872

# %% [markdown]
# ### Pridiction for if data of 75 row

# %%
my_model = model.predict([[0.09512,0.0,12.83,0,0.437,6.286,45.0,4.5026,5,398.0,18.7,383.23,8.94]])

# %%
my_model
# Out:
# array([[23.70637735]])

# %%
x_train.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     3.910872    9.754125   11.401089    0.075908    0.558029    6.255010
# std      9.730673   21.642752    6.799169    0.265288    0.114727    0.675894
# min      0.006320    0.000000    0.460000    0.000000    0.389000    3.561000
# 25%      0.089660    0.000000    5.750000    0.000000    0.453000    5.875500
# 50%      0.268380    0.000000    9.900000    0.000000    0.538000    6.167000
# 75%      3.735965    0.000000   18.100000    0.000000    0.631000    6.621500
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.704000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    69.681518    3.713708    9.676568  411.435644   18.439604  358.498350
# ...

# %% [markdown]
# ### Pridiction if 'CRIM' is max

# %%
my_model1 = model.predict([[88.976200,0.0,12.83,0,0.437,6.286,45.0,4.5026,5,398.0,18.7,383.23,8.94]])

# %%
my_model1
# Out:
# array([[11.93605603]])

# %% [markdown]
# ### Pridiction if 'CRIM','B' and 'ZN' is max

# %%
my_model2 = model.predict([[88.976200,95.000000,12.83,0,0.437,6.286,45.0,4.5026,5,398.0,18.7,396.900000,8.94]])

# %%
my_model2
# Out:
# array([[16.61592213]])

# %% [markdown]
# ### Pridiction if 'CRIM','ZN','B','INDUS' is max

# %%
my_model3 = model.predict([[88.976200,95.000000,27.740000,0,0.437,6.286,45.0,4.5026,5,398.0,18.7,396.900000,8.94]])

# %%
my_model3
# Out:
# array([[16.28121781]])

# %% [markdown]
# ### Pridiction if 'CRIM','ZN','INDUS' and 'CHAS' is max

# %%
my_model4 = model.predict([[88.976200,95.000000,27.740000,1,0.437,6.286,45.0,4.5026,5,398.0,18.7,396.900000,8.94]])

# %%
my_model4
# Out:
# array([[20.24695236]])

# %% [markdown]
# ### Pridiction if 'CRIM','ZN','INDUS','CHAS' and 'NOX' is max

# %%
my_model5 = model.predict([[88.976200,95.000000,27.740000,1,0.871000,6.286,45.0,4.5026,5,398.0,18.7,396.900000,8.94]])

# %%
my_model5
# Out:
# array([[15.13007827]])

# %% [markdown]
# ### Pridiction if 'CRIM','ZN','INDUS','CHAS','NOX' and 'RM' is max

# %%
my_model6 = model.predict([[88.976200,95.000000,27.740000,1,0.871000,8.704000,45.0,4.5026,5,398.0,18.7,396.900000,8.94]])

# %%
my_model6
# Out:
# array([[23.30457546]])

# %% [markdown]
# ### Pridiction if 'CRIM','ZN','INDUS','CHAS','NOX','RM' and'AGE' is max

# %%
my_model7 = model.predict([[88.976200,95.000000,27.740000,1,0.871000,8.704000,100.000000,4.5026,5,398.0,18.7,396.900000,8.94]])

# %%
my_model7
# Out:
# array([[24.03682837]])

# %% [markdown]
# ### Pridiction if all are max

# %%
m = model.predict([[88.976200,95.000000,27.740000,1.000000,0.871000,8.704000,100.000000,12.126500,24.000000,711.000000,21.200000,396.900000,36.980000]])

# %%
m
# Out:
# array([[-0.00515048]])

# %% [markdown]
# ### Pridiction at 50%

# %%
m1 = model.predict([[0.268380,0.000000,9.900000,0.000000,0.538000,6.167000,77.700000,3.102500,5.000000,330.000000,19.100000,391.980000,11.500000]])

# %%
m1
# Out:
# array([[22.73023042]])

# %% [markdown]
# ### Pridiction at min

# %%
price_min = model.predict([[0.006320,0.000000,0.460000,0.000000,0.389000,3.561000,2.900000,1.129600,1.000000,187.000000,12.600000,0.320000,1.920000]])

# %%
price_min
# Out:
# array([[24.16316649]])

# %%
model.coef_
# Out:
# array([[-1.32427749e-01,  4.77259220e-02, -2.24483116e-02,
#          3.96573455e+00, -1.17900324e+01,  3.38068536e+00,
#          1.33136892e-02, -1.05696931e+00,  2.62393302e-01,
#         -6.53844720e-03, -8.82075737e-01,  1.06732635e-02,
#         -5.96201853e-01]])

# %%
model.intercept_
# Out:
# array([31.09311728])

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,make)
# Out:
# 3.296080421476327

# %%
metrics.mean_squared_error(y_test,make)
# Out:
# 21.597716106733916
